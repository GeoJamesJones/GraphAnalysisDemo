# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Data\TransportationData\SEGMENT_ALL_CARRIER\611418118_T_T100I_SEGMENT_ALL_CARRIER.csv')

# %%
df.head()
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  PAYLOAD  SEATS  PASSENGERS  \
# 0                   0.0                   2.0  99520.0  144.0         0.0
# 1                   0.0                   1.0  49760.0   72.0        44.0
# 2                   0.0                   1.0  49760.0   72.0         0.0
# 3                   0.0                   1.0  49760.0   72.0        40.0
# 4                   0.0                   1.0  49760.0   72.0         0.0
#
#    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME UNIQUE_CARRIER  \
# 0      0.0   0.0     193.0         109.0      78.0             DL
# 1      0.0   0.0     214.0          90.0      38.0             DL
# 2      0.0   0.0    1284.0         290.0     115.0             DL
# 3      0.0   0.0     348.0          84.0      61.0             DL
# 4      0.0   0.0     440.0          83.0      70.0             DL
#
#     UNIQUE_CARRIER_NAME  ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID DEST  \
# 0  Delta Air Lines Inc.              11042    CLE            16271  YYZ
# 1  Delta Air Lines Inc.              11433    DTW            16271  YYZ
# 2  Delta Air Lines Inc.              11618    EWR            16232  YWG
# 3  Delta Air Lines Inc.              11618    EWR            16271  YYZ
# 4  Delta Air Lines Inc.              12339    IND            16271  YYZ
#
#    AIRCRAFT_TYPE  MONTH  Unnamed: 18
# 0            622      1          NaN
# 1            622      1          NaN
# 2            622      1          NaN
# 3            622      1          NaN
# 4            622      1          NaN

# %%
df.shape
# Out:
# (15798, 19)

# %%
from arcgis import GIS

gis = GIS(r'http://esrifederal.maps.arcgis.com', 'james_jones_federal')
# Out:
# Enter password: ········

# %%
from arcgis.features import *

airports = gis.content.get('0cc3ab28ce7847c5b856154e9d84c687')
airports_lyr = airports.layers[0]
sdf = airports_lyr.query(where="1=1").sdf
sdf.head()
# Out:
#    OBJECTID  OBJECTID_1                                              SHAPE  \
# 0         1           1  {"x": -8341570.3489, "y": 4876236.196500003, "...
# 1         2           2  {"x": -16886721.3803, "y": 8388436.432499997, ...
# 2         3           3  {"x": -9659225.8145, "y": 4145523.0812000036, ...
# 3         4           4  {"x": -10158448.7857, "y": 4246911.7918, "spat...
# 4         5           5  {"x": -12486150.7867, "y": 4069910.7205, "spat...
#
#   continent  elevation_ gps_code home_link iata_code    id ident    ...      \
# 0        NA          11      00A                      6523   00A    ...
# 1        NA         450     00AK                      6524  00AK    ...
# 2        NA         820     00AL                      6525  00AL    ...
# 3        NA         237     00AR                      6526  00AR    ...
# 4        NA        3810     00AZ                      6527  00AZ    ...
#
#   iso_region keywords latitude_d  local_code  longitude_    municipali  \
# 0      US-PA           40.070801         00A  -74.933601      Bensalem
# 1      US-AK           59.949200        00AK -151.695999  Anchor Point
# 2      US-AL           34.864799        00AL  -86.770302       Harvest
# 3      US-AR           35.608700        00AR  -91.254898       Newport
# 4      US-AZ           34.305599        00AZ -112.165001        Cordes
#
#                                  name scheduled_           type wikipedia_
# 0                   Total Rf Heliport         no       heliport
# 1                        Lowell Field         no  small_airport
# 2                        Epps Airpark         no  small_airport
# 3  Newport Hospital & Clinic Heliport         no       heliport
# 4                      Cordes Airport         no  small_airport
#
# [5 rows x 21 columns]

# %%
sdf.shape
# Out:
# (47997, 21)

# %%
G = nx.Graph()
mG = nx.MultiDiGraph()
edges = mG.edges(keys=True)

# %%
airports = {}

for row in sdf.iterrows():
    ident = row[1]['iata_code']
    lat = row[1]['latitude_d']
    long = row[1]['longitude_']
    airports[ident] = [long, lat]

# %%
for row in df.iterrows():
    carrier = row[1]['UNIQUE_CARRIER_NAME']
    origin = row[1]['ORIGIN']
    destination = row[1]['DEST']
    payload = row[1]['PAYLOAD']
    passengers = row[1]['PASSENGERS']
    freight = row[1]['FREIGHT']
    mail = row[1]['MAIL']
    distance = row[1]['DISTANCE']
    travel_time = row[1]['RAMP_TO_RAMP']

    G.add_edge(origin, destination, carrier=carrier, distance=distance, travel_time=travel_time)
    
    mG.add_edge(origin, destination, carrier=carrier, passengers=passengers, payload=payload, 
               freight=freight, mail=mail, distance=distance, travel_time=travel_time)

# %%
print("Total number of nodes in simple graph:  " + repr(len(G.nodes)))
print("Total number of nodes in multi graph:  " + repr(len(mG.nodes)))
# Out:
# Total number of nodes in simple graph:  594
# Total number of nodes in multi graph:  594

# %%
print("Total number of edges in simple graph:  " + repr(len(G.edges)))
print("Total number of edges in multi graph:  " + repr(len(mG.edges)))
# Out:
# Total number of edges in simple graph:  2417
# Total number of edges in multi graph:  15798

# %%
for node in G.nodes.data():
    if node[0] in airports:
        shape = airports[node[0]]
        node[1]['long'] = shape[0]
        node[1]['lat'] = shape[1]

# %%
for node in mG.nodes.data():
    if node[0] in airports:
        shape = airports[node[0]]
        node[1]['long'] = shape[0]
        node[1]['lat'] = shape[1]

# %%
G.nodes.data()
# Out:
# NodeDataView({'CLE': {'long': -81.8498001099, 'lat': 41.4117012024}, 'YYZ': {'long': -79.6305999756, 'lat': 43.6772003174}, 'DTW': {'long': -83.3534011841, 'lat': 42.2123985291}, 'EWR': {'long': -74.1687011719, 'lat': 40.6925010681}, 'YWG': {'long': -97.2398986816, 'lat': 49.9099998474}, 'IND': {'long': -86.2944030762, 'lat': 39.717300415}, 'JFK': {'long': -73.77890015, 'lat': 40.63980103}, 'LAX': {'long': -118.4079971, 'lat': 33.94250107}, 'YVR': {'long': -123.183998108, 'lat': 49.193901062}, 'MDW': {'long': -87.7524032593, 'lat': 41.7859992981}, 'MKE': {'long': -87.8965988159, 'lat': 42.9472007751}, 'MSP': {'long': -93.2218017578, 'lat': 44.8819999695}, 'YEG': {'long': -113.580001831, 'lat': 53.3097000122}, 'PDX': {'long': -122.5979996, 'lat': 45.58869934}, 'YYC': {'long': -114.019996643, 'lat': 51.113899231}, 'PHL': {'long': -75.2410964966, 'lat': 39.8718986511}, 'PIT': {'long': -80.23290253, 'lat': 40.49150085}, 'PTK': {'long': -83.4200973511, 'lat': 42.6655006409}, 'SLC': {'long': -111.977996826, 'lat': 40.7883987427}, 'SMF': {'long': -121.591003418, 'lat': 38.695400238}, 'SNA': {'long': -117.8679962, 'lat': 33.67570114}, 'YOW': {'long': -75.6691970825, 'lat': 45.3224983215}, 'ATL': {'long': -84.4281005859, 'lat': 33.6366996765}, 'BUF': {'long': -78.73220062, 'lat': 42.94049835}, 'OKC': {'long': -97.6007003784, 'lat': 35.3931007385}, 'BED': {'long': -71.28900146, 'lat': 42.47000122}, 'PHX': {'long': -112.012001038, 'lat': 33.434299469}, 'YYR': {'long': -60.4258003235, 'lat': 53.3191986084}, 'BOS': {'long': -71.00520325, 'lat': 42.36429977}, 'BNA': {'long': -86.6781997681, 'lat': 36.1245002747}, 'IAD': {'long': -77.45580292, 'lat': 38.94449997}, 'MCO': {'long': -81.3089981079, 'lat': 28.4293994904}, 'SAT': {'long': -98.4698028564, 'lat': 29.533700943}, 'BDA': {'long': -64.6787033081, 'lat': 32.3639984131}, 'CUN': {'long': -86.8770980835, 'lat': 21.0365009308}, 'CZM': {'long': -86.9255981445, 'lat': 20.5223999023}, 'GRU': {'long': -46.4730567932, 'lat': -23.4355564117}, 'GYE': {'long': -79.8835983276, 'lat': -2.15741991997}, 'MBJ': {'long': -77.9133987427, 'lat': 18.5037002563}, 'MEX': {'long': -99.0720977783, 'lat': 19.4363002777}, 'MVD': {'long': -56.0307998657, 'lat': -34.8384017944}, 'PAP': {'long': -72.2925033569, 'lat': 18.5799999237}, 'PTY': {'long': -79.3834991455, 'lat': 9.0713596344}, 'PUJ': {'long': -68.3634033203, 'lat': 18.5673999786}, 'SAP': {'long': -87.9235992432, 'lat': 15.4525995255}, 'SDQ': {'long': -69.6688995361, 'lat': 18.4297008514}, 'SJD': {'long': -109.721000671, 'lat': 23.1518001556}, 'STI': {'long': -70.6046981812, 'lat': 19.4060993195}, 'AUA': {'long': -70.0151977539, 'lat': 12.5013999939}, 'MIA': {'long': -80.2906036377, 'lat': 25.7931995392}, 'BOG': {'long': -74.1469, 'lat': 4.70159}, 'BWI': {'long': -76.66829681, 'lat': 39.17539978}, 'MEM': {'long': -89.9766998291, 'lat': 35.0424003601}, 'PVR': {'long': -105.253997803, 'lat': 20.6800994873}, 'SAL': {'long': -89.0557022095, 'lat': 13.4408998489}, 'LIM': {'long': -77.1143035889, 'lat': -12.021900177}, 'MZT': {'long': -106.26599884, 'lat': 23.1613998413}, 'MTY': {'long': -100.107002258, 'lat': 25.7784996033}, 'DFW': {'long': -97.0380020142, 'lat': 32.8968009949}, 'ONT': {'long': -117.600997925, 'lat': 34.0559997559}, 'RTB': {'long': -86.523003, 'lat': 16.316799}, 'TPA': {'long': -82.533203125, 'lat': 27.9755001068}, 'SKB': {'long': -62.7187004089, 'lat': 17.3111991882}, 'ZIH': {'long': -101.460998535, 'lat': 17.601600647}, 'AMS': {'long': 4.76388978958, 'lat': 52.3086013794}, 'BRU': {'long': 4.48443984985, 'lat': 50.9014015198}, 'CDG': {'long': 2.54999995232, 'lat': 49.0127983093}, 'FRA': {'long': 8.54313, 'lat': 50.026402}, 'ZRH': {'long': 8.54916954041, 'lat': 47.4646987915}, 'BCN': {'long': 2.0784599781, 'lat': 41.2971000671}, 'SEA': {'long': -122.308998108, 'lat': 47.4490013123}, 'DUB': {'long': -6.27007007599, 'lat': 53.4212989807}, 'EDI': {'long': -3.37249994278, 'lat': 55.9500007629}, 'FCO': {'long': 12.2508001328, 'lat': 41.8045005798}, ' ...

# %%
# Calculate Graph Density
graph_density = nx.density(G)
multigraph_density = nx.density(mG)
print("Simple graph density:  " + repr(graph_density))
print("Multi graph density:  " + repr(multigraph_density))
# Out:
# Simple graph density:  0.013723519625711868
# Multi graph density:  0.04484984754799257

# %%
graph_info = nx.info(G)
print("Simple Graph Information")
print(graph_info)
# Out:
# Simple Graph Information
# Name:
# Type: Graph
# Number of nodes: 594
# Number of edges: 2417
# Average degree:   8.1380

# %%
graph_info = nx.info(mG)
print("MultiGraph Information")
print(graph_info)
# Out:
# MultiGraph Information
# Name:
# Type: MultiDiGraph
# Number of nodes: 594
# Number of edges: 15798
# Average in degree:  26.5960
# Average out degree:  26.5960

# %%
# Calculate number of components
simple_components = nx.number_connected_components(G)
print("Number of connected components:  " + repr(simple_components))
# Out:
# Number of connected components:  5

# %%
#  Compute Degree Centrality
degree = dict(mG.degree())
nx.set_node_attributes(mG, name='degree', values=degree)

degree_s = dict(G.degree())
nx.set_node_attributes(G, name='degree', values=degree)

# %%
#  Compute In-Degree/Out-Degree Centrality
in_degree = dict(nx.in_degree_centrality(mG))
out_degree = dict(nx.out_degree_centrality(mG))
nx.set_node_attributes(mG, name='in degree', values=in_degree)
nx.set_node_attributes(mG, name='out degree', values=out_degree)

# %%
#  Compute Closeness Centrality
closeness = dict(nx.closeness_centrality(mG))
nx.set_node_attributes(mG, name='closeness', values=closeness)

closeness_s = dict(nx.closeness_centrality(G))
nx.set_node_attributes(G, name='closeness', values=closeness_s)

# %%
#  Compute Betweenness Centrality for nodes and edges
node_betweenness = dict(nx.betweenness_centrality(mG))
nx.set_node_attributes(mG, name='betweenness', values=node_betweenness)

node_betweenness_s = dict(nx.betweenness_centrality(G))
nx.set_node_attributes(G, name='betweenness', values=node_betweenness_s)

edge_betweenness_s = dict(nx.edge_betweenness_centrality(G))
nx.set_edge_attributes(G, name='betweenness', values=edge_betweenness_s)

# %%
# Compute Pagerank for the graph
simple_pagerank = dict(nx.pagerank(G, alpha=0.9))
nx.set_node_attributes(G, name='pagerank', values=simple_pagerank)

# %%
# View Information about an Individual Node
nodes_list = dict(G.nodes.data())
nodes_list['IAD']
# Out:
# {'long': -77.45580292,
#  'lat': 38.94449997,
#  'degree': 386,
#  'closeness': 0.376836708786378,
#  'betweenness': 0.03458290281777038,
#  'pagerank': 0.012026576722275938}

# %%
# Examine all of the neighbors of a node
charlotte_neighbors = nx.all_neighbors(mG, 'CLT')
print(list(charlotte_neighbors))
# Out:
# ['AUA', 'YUL', 'YYZ', 'MUC', 'GCM', 'BCN', 'FRA', 'LHR', 'LIR', 'SJD', 'SKB', 'BZE', 'CUN', 'CZM', 'FPO', 'PLS', 'POP', 'NAS', 'PUJ', 'UVF', 'GGT', 'ANU', 'BGI', 'CUR', 'MBJ', 'MEX', 'SJO', 'HAV', 'PTY', 'AUA', 'YYZ', 'MUC', 'YXU', 'GCM', 'FRA', 'LIR', 'SJD', 'SKB', 'LHR', 'CUN', 'BZE', 'CZM', 'FPO', 'PLS', 'POP', 'NAS', 'PUJ', 'UVF', 'GGT', 'ANU', 'BGI', 'CUR', 'MBJ', 'MEX', 'SJO', 'HAV', 'YUL']

# %%
# Examine all of the neighbors of a node
rdu_neighbors = nx.all_neighbors(mG, 'RDU')
print(list(rdu_neighbors))
# Out:
# ['YOW', 'YYZ', 'YUL', 'CUN', 'CDG', 'LHR', 'YOW', 'YYC', 'YYZ', 'LIR', 'YUL', 'CUN', 'CDG', 'LHR']

# %%
# Find common neighbors between two nodes
common_neighbors = nx.common_neighbors(G, 'CLT', 'RDU')
print(list(common_neighbors))
# Out:
# ['YUL', 'YYZ', 'LHR', 'LIR', 'CUN']

# %%
# Find the Shortest Path between two nodes based on travel time
shortest_path_tt = list(nx.shortest_path(mG, 'RDU', 'LAX', travel_time))
shortest_path_tt
# Out:
# ['RDU', 'YOW', 'LAX']

# %%
# Find any bridges in the graph
bridges = list(nx.bridges(G))
bridges
# Out:
# [('YYZ', 'LAR'),
#  ('YYZ', 'GRK'),
#  ('YYZ', 'INT'),
#  ('YYZ', 'APF'),
#  ('YYZ', 'BLM'),
#  ('YYZ', 'CHA'),
#  ('YYZ', 'LEB'),
#  ('YYZ', 'LWB'),
#  ('YYZ', 'PAH'),
#  ('YYZ', 'UST'),
#  ('YYZ', 'MKC'),
#  ('YYZ', 'MDT'),
#  ('YYZ', 'ACY'),
#  ('YYZ', 'AGS'),
#  ('YYZ', 'ERI'),
#  ('YYZ', 'FCM'),
#  ('YYZ', 'MSN'),
#  ('YYZ', 'MSO'),
#  ('YYZ', 'RST'),
#  ('YYZ', 'AVP'),
#  ('EWR', 'LBA'),
#  ('EWR', 'BOM'),
#  ('EWR', 'AMD'),
#  ('YWG', 'DLH'),
#  ('JFK', 'ZAZ'),
#  ('JFK', 'RIX'),
#  ('JFK', 'LCY'),
#  ('JFK', 'FOC'),
#  ('JFK', 'ALG'),
#  ('JFK', 'KBP'),
#  ('JFK', 'BEG'),
#  ('JFK', 'CAI'),
#  ('LAX', 'TNA'),
#  ('LAX', 'XMN'),
#  ('LAX', 'RAR'),
#  ('LAX', 'UPN'),
#  ('LAX', 'LTO'),
#  ('LAX', 'VVO'),
#  ('LAX', 'CSX'),
#  ('LAX', 'TLS'),
#  ('LAX', 'NKG'),
#  ('LAX', 'VRN'),
#  ('YVR', 'SBA'),
#  ('YVR', 'SUN'),
#  ('YVR', 'LIH'),
#  ('YEG', 'CID'),
#  ('YEG', 'OLM'),
#  ('PDX', 'OAI'),
#  ('YYC', 'PSC'),
#  ('PHL', 'NUE'),
#  ('PTK', 'KLV'),
#  ('PTK', 'YMM'),
#  ('YOW', 'ABE'),
#  ('ATL', 'PKC'),
#  ('ATL', 'LOS'),
#  ('PHX', 'CUL'),
#  ('YYR', 'UXP'),
#  ('YYR', 'CWA'),
#  ('BOS', 'PDL'),
#  ('IAD', 'BBU'),
#  ('IAD', 'PRG'),
#  ('IAD', 'CAY'),
#  ('MCO', 'YQM'),
#  ('MCO', 'MEC'),
#  ('CUN', 'SPI'),
#  ('SJD', 'SBD'),
#  ('MIA', 'BLA'),
#  ('MIA', 'RMS'),
#  ('MIA', 'AGT'),
#  ('MIA', 'ASU'),
#  ('MIA', 'MAO'),
#  ('MIA', 'BAQ'),
#  ('MIA', 'CLO'),
#  ('MIA', 'CWB'),
#  ('MIA', 'CCS'),
#  ('MIA', 'CFG'),
#  ('MIA', 'SCU'),
#  ('MIA', 'BSB'),
#  ('MIA', 'CFB'),
#  ('MIA', 'SSA'),
#  ('MIA', 'VIX'),
#  ('MIA', 'POA'),
#  ('MIA', 'SNR'),
#  ('MIA', 'MAR'),
#  ('MIA', 'CYB'),
#  ('MIA', 'FOR'),
#  ('MIA', 'PBM'),
#  ('MIA', 'SVD'),
#  ('MIA', 'NBW'),
#  ('MIA', 'VVI'),
#  ('MIA', 'ZSA'),
#  ('MIA', 'CAP'),
#  ('MIA', 'LPB'),
#  ('MTY', 'HRL'),
#  ('DUB', 'RIL'),
#  ('CVG', 'BAH'),
#  ('CVG', 'SHJ'),
#  ('HNL', 'APW'),
#  ('HNL', 'CXI'),
#  ('HNL', 'HKD'),
#  ('ANC', 'KOJ'),
#  ('ANC', 'KHH'),
#  ('FBS', 'YWH'),
#  ('YWH', 'RCE'),
#  ('LKE', 'YIG'),
#  ('YYJ', 'CLM'),
#  ('YYJ', 'HIO'),
#  ('KEH', 'YHH'),
#  ('KEH', 'ZNA'),
#  ('LCK', 'CMB'),
#  ('LCK', 'HAN'),
#  ('LCK', 'SGN'),
#  ('IAH', 'LAD'),
#  ('IAH', 'VER'),
#  ('ORD', 'KRK'),
#  ('ORD', 'DME'),
#  ('GDL', 'MTO'),
#  ('QRO', 'JZT'),
#  ('FGI', 'PPG'),
#  ('PPG', 'TBU'),
#  ('PPG', 'AKL'),
#  ('GUM', 'ROR'),
#  ('GUM', 'TKK'),
#  ('GUM', 'PNI'),
#  ('GUM', 'DAC'),
#  ('GUM', 'KIJ'),
#  ('GUM', 'DLC'),
#  ('GUM', 'YAP'),
#  ('GUM', 'SDJ'),
#  ('MAN', 'PSM'),
#  ('BGR', 'BSL'),
#  ('BGR', 'BLK'),
#  ('FLL', 'MLA'),
#  ('FLL', 'LPL'),
#  ('FLL', 'CIX'),
#  ('FLL', 'ON1'),
#  ('FLL', 'AXM'),
#  ('FLL', 'GHB'),
#  ('YUL', 'TYS'),
#  ('YUL', 'AFW'),
#  ('YUL', 'CHO'),
#  ('SJU', 'DOM'),
#  ('SJU', 'VIJ'),
#  ('SJU', 'MST'),
#  ('DOV', 'LGG'),
#  ('OKO', 'SUU'),
#  ('UAM', 'OSN'),
#  ('YHZ', 'LSV'),
#  ('CHS', 'BRI'),
#  ('KEF', 'DHN'),
#  ('GUA', 'ABQ'),
#  ('LIR', 'TCM'),
#  ('SFO', 'RTM'),
#  ('PBI', 'YYB'),
#  ('PBI', 'AGP'),
#  ('VCP', 'BHM'),
#  ('WAW', 'GJT'),
#  ('NAS', 'GRR'),
#  ('NAS', 'MTJ'),
#  ('NAS', 'NEW'),
#  ('NAS', 'BTR'),
#  ('BIM', 'N2C'),
#  ('ISO', 'CHR'),
#  ('ISO', 'LYS'),
#  ('CHR', 'RQZ'),
#  ('ANU', 'ADS'),
#  ('HPN', 'YAM'),
#  ('TEB', 'YCM'),
#  ('TEB', 'FMO'),
#  ('TEB', 'ESB'),
#  ('TEB', 'GWT'),
#  ('TEB', 'LIN'),
#  ('YCM', 'GON'),
#  ('OPF', 'SGD'),
#  ('OPF', 'SZG'),
#  ('OPF', 'PSA'),
#  ('BFS', 'SWF'),
#  ('SWF', 'BGO'),
#  ('SWF', 'BOD'),
#  ('PVD', 'ORK'),
#  ('HOW', 'PSE'),
#  ('YLW', 'GCC'),
#  ('JAX', 'YLS'),
#  ('TCB', 'FPR'),
#  ('YLS', 'SUA'),
#  ('CUU', 'LBB'),
#  ('SBD', 'NIM'),
#  ('KLW', 'YPR'),
#  ('YPR', 'KTN'),
#  ('REC', 'ACT'),
#  ('BCT', 'MRS'),
#  ('SDM', 'YXS'),
#  ('TUS', 'XCR'),
#  ('BOJ', 'PSM'),
#  ('BLK', 'LUK'),
#  ('GGT', 'TN8')]

# %%
cliques = list(nx.find_cliques(G))
large_cliques = [clique for clique in cliques if len(clique) >= 2]
large_cliques
# Out:
# [['ILM', 'POP'],
#  ['ILM', 'BIM'],
#  ['ILM', 'GOT'],
#  ['SDJ', 'GUM'],
#  ['MSO', 'YYZ'],
#  ['ZAZ', 'JFK'],
#  ['MST', 'SJU'],
#  ['EDI', 'LAX'],
#  ['EDI', 'EWR'],
#  ['EDI', 'BDL'],
#  ['EDI', 'DTW'],
#  ['EDI', 'SWF'],
#  ['EDI', 'IAH'],
#  ['EDI', 'JFK'],
#  ['EDI', 'PVD'],
#  ['PPT', 'LAX'],
#  ['PPT', 'HNL'],
#  ['PPT', 'TEB'],
#  ['OSN', 'UAM'],
#  ['CTU', 'JFK'],
#  ['CTU', 'SFO'],
#  ['CTU', 'LAX'],
#  ['CHO', 'YUL'],
#  ['BON', 'FLL'],
#  ['BON', 'EWR'],
#  ['BON', 'IAH'],
#  ['BON', 'ATL'],
#  ['SUN', 'YVR'],
#  ['MN7', 'YYZ'],
#  ['MN7', 'SJD'],
#  ['PIT', 'CUN'],
#  ['PIT', 'YVR'],
#  ['PIT', 'SDQ'],
#  ['PIT', 'YOW'],
#  ['PIT', 'MAN'],
#  ['PIT', 'KEF'],
#  ['PIT', 'YYZ'],
#  ['PIT', 'YUL'],
#  ['PIT', 'PUJ'],
#  ['FAR', 'MBJ'],
#  ['FAR', 'PVR'],
#  ['FAR', 'YVR'],
#  ['FAR', 'YWG'],
#  ['FAR', 'AUA'],
#  ['FAR', 'YYZ'],
#  ['FAR', 'SJD'],
#  ['PEK', 'IAD'],
#  ['PEK', 'ORD'],
#  ['PEK', 'EWR'],
#  ['PEK', 'ANC'],
#  ['PEK', 'LAX'],
#  ['PEK', 'DFW'],
#  ['PEK', 'SFO'],
#  ['PEK', 'DTW'],
#  ['PEK', 'BOS'],
#  ['PEK', 'SJC'],
#  ['PEK', 'SPN'],
#  ['PEK', 'SEA'],
#  ['PEK', 'IAH'],
#  ['PEK', 'JFK'],
#  ['PEK', 'LAS'],
#  ['PEK', 'HNL'],
#  ['GWT', 'TEB'],
#  ['MKC', 'YYZ'],
#  ['BJX', 'AUS'],
#  ['BJX', 'LRD'],
#  ['BJX', 'SHV'],
#  ['BJX', 'ATL'],
#  ['BJX', 'OAK'],
#  ['BJX', 'LAX'],
#  ['BJX', 'MDW'],
#  ['BJX', 'DFW'],
#  ['BJX', 'BRO'],
#  ['BJX', 'TUS'],
#  ['BJX', 'IAH'],
#  ['BJX', 'ONT'],
#  ['BJX', 'SAT'],
#  ['MSN', 'YYZ'],
#  ['GON', 'YCM'],
#  ['CUU', 'LBB'],
#  ['CUU', 'LRD'],
#  ['CUU', 'SAT'],
#  ['CUU', 'DFW'],
#  ['CUU', 'DEN'],
#  ['CUU', 'TUS'],
#  ['CUU', 'IAH'],
#  ['CUU', 'ELP'],
#  ['GJT', 'WAW'],
#  ['MRY', 'YEG'],
#  ['MRY', 'BRN'],
#  ['MRY', 'SNN'],
#  ['FAI', 'YVR'],
#  ['FAI', 'NGO'],
#  ['CLE', 'PUJ'],
#  ['CLE', 'CUN'],
#  ['CLE', 'MAD'],
#  ['CLE', 'YOW'],
#  ['CLE', 'YYZ'],
#  ['CLE', 'YUL'],
#  ['CLE', 'KEF'],
#  ['CLE', 'TLC'],
#  ['CXI', 'HNL'],
#  ['ROR', 'GUM'],
#  ['SEA', 'PVR'],
#  ['SEA', 'CDG'],
#  ['SEA', 'NRT'],
#  ['SEA', 'LHR'],
#  ['SEA', 'PVG'],
#  ['SEA', 'DXB'],
#  ['SEA', 'ICN'],
#  ['SEA', 'MEX'],
#  ['SEA', 'CUN'],
#  ['SEA', 'AMS'],
#  ['SEA', 'FRA'],
#  ['SEA', 'YYC'],
#  ['SEA', 'HKG'],
#  ['SEA', 'YYZ'],
#  ['SEA', 'SJD'],
#  ['SEA', 'LGW'],
#  ['SEA', 'GDL'],
#  ['SEA', 'LUX'],
#  ['SEA', 'YKA'],
#  ['SEA', 'YMX'],
#  ['SEA', 'YYJ'],
#  ['SEA', 'KEF'],
#  ['SEA', 'YVR'],
#  ['SEA', 'TPE'],
#  ['SEA', 'SZX'],
#  ['SEA', 'BCN'],
#  ['SEA', 'YEG'],
#  ['SEA', 'YLW'],
#  ['PIE', 'YYZ'],
#  ['PIE', 'YHZ'],
#  ['SAN', 'YXX'],
#  ['SAN', 'MEX'],
#  ['SAN', 'PVR'],
#  ['SAN', 'YVR'],
#  ['SAN', 'SJO'],
#  ['SAN', 'NRT'],
#  ['SAN', 'FUK'],
#  ['SAN', 'LHR'],
#  ['SAN', 'YYC'],
#  ['SAN', 'YYZ'],
#  ['SAN', 'SJD'],
#  ['CLT', 'MBJ'],
#  ['CLT', 'CUR'],
#  ['CLT', 'GGT'],
#  ['CLT', 'SKB'],
#  ['CLT', 'CZM'],
#  ['CLT', 'LHR'],
#  ['CLT', 'POP'],
#  ['CLT', 'YXU'],
#  ['CLT', 'AUA'],
#  ['CLT', 'UVF'],
#  ['CLT', 'HAV'],
#  ['CLT', 'NAS'],
#  ['CLT', 'PLS'],
#  ['CLT', 'CUN'],
#  ['CLT', 'MEX'],
#  ['CLT', 'PTY'],
#  ['CLT', 'SJO'],
#  ['CLT', 'BGI'],
#  ['CLT', 'LIR'],
#  ['CLT', 'ANU'],
#  ['CLT', 'GCM'],
#  ['CLT', 'FRA'],
#  ['CLT', 'BZE'],
#  ['CLT', 'BCN'],
#  ['CLT', 'YYZ'],
#  ['CLT', 'YUL'],
#  ['CLT', 'SJD'],
#  ['CLT', 'PUJ'],
#  ['CLT', 'MUC'],
#  ['CLT', 'FPO'],
#  ['PDK', 'YYZ'],
#  ['PDK', 'YKF'],
#  ['PDK', 'BIM'],
#  ['YQR', 'DAL'],
#  ['YQR', 'SCF'],
#  ['YQR', 'PHX'],
#  ['YQR', 'ORD'],
#  ['YQR', 'CPR'],
#  ['YQR', 'STP'],
#  ['YQR', 'IAH'],
#  ['YQR', 'LAS'],
#  ['YQR', 'MCO'],
#  ['CHR', 'RQZ'],
#  ['CHR', 'ISO'],
#  ['UST', 'YYZ'],
#  ['EIS', 'SIG'],
#  ['EIS', 'SJU'],
#  ['EIS', 'STT'],
#  ['EIS', 'STX'],
#  ['BRN', 'BGR'],
#  ['HAM', 'EWR'],
#  ['HAM', 'PBI'],
#  ['HAN', 'LCK'],
#  ['ATL', 'MTY'],
#  ['ATL', 'BOG'],
#  ['ATL', 'CDG'],
#  ['ATL', 'GRU'],
#  ['ATL', 'GYE'],
#  ['ATL', 'SXM'],
#  ['ATL', 'GIG'],
#  ['ATL', 'YHZ'],
#  ['ATL', 'ICN'],
#  ['ATL', 'MEX'],
#  ['ATL', 'SJO'],
#  ['ATL', 'AMS'],
#  ['ATL', 'FRA'],
#  ['ATL', 'SCL'],
#  ['ATL', 'DUB'],
#  ['ATL', 'PKC'],
#  ['ATL', 'SDQ'],
#  ['ATL', 'GDL'],
#  ['ATL', 'EZE'],
#  ['ATL', 'QRO'],
#  ['ATL', 'HAV'],
#  ['ATL', 'NAS'],
#  ['ATL', 'STN'],
#  ['ATL', 'CZM'],
#  ['ATL', 'PLS'],
#  ['ATL', 'MUC'],
#  ['ATL', 'MAD'],
#  ['ATL', 'CTG'],
#  ['ATL', 'NRT'],
#  ['ATL', 'IST'],
#  ['ATL', 'SAL'],
#  ['ATL', 'PTP'],
#  ['ATL', 'GUA'],
#  ['ATL', 'SNN'],
#  ['ATL', 'ZRH'],
#  ['ATL', 'DOH'],
#  ['ATL', 'GYD'],
#  ['ATL', 'BDA'],
#  ['ATL', 'LUX'],
#  ['ATL', 'SKB'],
#  ['ATL', 'UIO'],
#  ['ATL', 'GCM'],
#  ['ATL', 'MGA'],
#  ['ATL', 'JNB'],
#  ['ATL', 'LGG'],
#  ['ATL', 'PAP'],
#  ['ATL', 'KIN'],
#  ['ATL', 'PVR'],
#  ['ATL', 'YOW'],
#  ['ATL', 'LHR'],
#  ['ATL', 'STI'],
#  ['ATL', 'AUA'],
#  ['ATL', 'PTY'],
#  ['ATL', 'LIR'],
#  ['ATL', 'ANU'],
#  ['ATL', 'YYZ'],
#  ['ATL', 'PUJ'],
#  ['ATL', 'FPO'],
#  ['ATL', 'GGT'],
#  ['ATL', 'OST'],
#  ['ATL', 'TGU'],
#  ['ATL', 'MVD'],
#  ['ATL', 'SAP'],
#  ['ATL', 'KEF'],
#  ['ATL', 'MID'],
#  ['ATL', 'YVR'],
#  ['ATL', 'MZT'],
#  ['ATL', 'DUS'],
#  ['ATL', 'ZIH'],
#  ['ATL', 'LIM'],
#  ['ATL', 'CUN'],
#  ['ATL', 'GND'],
#  ['ATL', 'BZE'],
#  ['ATL', 'MHH'],
#  ['ATL', 'YHM'],
#  ['ATL', 'YUL'],
#  ['ATL', 'SJD'],
#  ['ATL', 'SVO'],
#  ['ATL', 'MBJ'],
#  ['ATL', 'ELH'],
#  ['ATL', 'RTB'],
#  ['ATL', 'YYT'],
#  ['ATL', 'UVF'],
#  ['ATL', 'FCO'],
#  ['ATL', 'LOS'],
#  ['ATL', 'BRU'],
#  ['ATL', 'TLV'],
#  ['ATL', 'MAN'],
#  ['ATL', 'STR'],
#  ['AMA', 'QRO'],
#  ['AMA', 'AGU'],
#  ['DAY', 'QRO'],
#  ['DAY', 'SJO'],
#  ['BNE', 'LAX'],
#  ['BNE', 'HNL'],
#  ['AFW', 'YUL'],
#  ['FSD', 'MBJ'],
#  ['FSD', 'YYC'],
#  ['FSD', 'YWG'],
#  ['JNB', 'JFK'],
#  ['JNB', 'MCO'],
#  ['MSY', 'GUA'],
#  ['MSY', 'CUN'],
#  ['MSY', 'PTY'],
#  ['MSY', 'BGI'],
#  ['MSY', 'RTB'],
#  ['MSY', 'SLW'],
#  ['MSY', 'LHR'],
#  ['MSY', 'SAL'],
#  ['MSY', 'MGA'],
#  ['MSY', 'YQB'],
#  ['MSY', 'YYZ'],
#  ['MSY', 'YUL'],
#  ['AUH', 'IAD'],
#  ['AUH', 'ORD'],
#  ['AUH', 'LAX'],
#  ['AUH', 'DFW'],
#  ['AUH', 'JFK'],
#  ['HHN', 'LCK'],
#  ['HHN', 'HSV'],
#  ['HHN', 'GSP'],
#  ['HHN', 'ORD'],
#  ['SUU', 'OKO'],
#  ['AXM', 'FLL'],
#  ['HKG', 'IAD'],
#  ['HKG', 'MEM'],
#  ['HKG', 'ORD'],
#  ['HKG', 'LAX'],
#  ['HKG', 'ANC'],
#  ['HKG', 'EWR'],
#  ['HKG', 'LCK'],
#  ['HKG', 'CVG'],
#  ['HKG', 'DFW'],
#  ['HKG', 'BOS'],
#  ['HKG', 'SPN'],
#  ['HKG', 'PDX'],
#  ['HKG', 'JFK'],
#  ['HKG', 'SFO'],
#  ['HKG', 'GUM'],
#  ['HKG', 'HNL'],
#  ['ASE', 'ANU'],
#  ['ASE', 'LIR'],
#  ['ASE', 'YLW'],
#  ['STP', 'YYZ'],
#  ['FLL', 'BOG'],
#  ['FLL', 'CDG'],
#  ['FLL', 'GYE'],
#  ['FLL', 'YOW'],
#  ['FLL', 'CMW'],
#  ['FLL', 'STI'],
#  ['FLL', 'AUA'],
#  ['FLL', 'YHZ'],
#  ['FLL', 'MEX'],
#  ['FLL', 'PTY'],
#  ['FLL', 'SJO'],
#  ['FLL', 'ANU'],
#  ['FLL', 'LIR'],
#  ['FLL', 'YYZ'],
#  ['FLL', 'BIM'],
#  ['FLL', 'PUJ'],
#  ['FLL', 'FPO'],
#  ['FLL', 'GGT'],
#  ['FLL', 'SDQ'],
#  ['FLL', 'POP'],
#  ['FLL', 'SAP'],
#  ['FLL', 'HAV'],
#  ['FLL', 'NAS'],
#  ['FLL', 'YVR'],
#  ['FLL', 'BGI'],
#  ['FLL', 'HOG'],
#  ['FLL', 'PLS'],
#  ['FLL', 'VCP'],
#  ['FLL', 'MLA'],
#  ['FLL', 'CIX'],
#  ['FLL', 'CTG'],
#  ['FLL', 'GHB'],
#  ['FLL', 'SAL'],
#  ['FLL', 'PTP'],
#  ['FLL', 'YQB'],
#  ['FLL', 'CNF'],
#  ['FLL', 'LIM'],
#  ['FLL', 'DXB'],
#  ['FLL', 'GUA'],
#  ['FLL', 'CUN'],
#  ['FLL', 'SNN'],
#  ['FLL', 'OSL'],
#  ['FLL', 'BZE'],
#  ['FLL', 'MDE'],
#  ['FLL', 'POS'],
#  ['FLL', 'YYC'],
#  ['FLL', 'CPH'],
#  ['FLL', 'MHH'],
#  ['FLL', 'LPL'],
#  ['FLL', 'YUL'],
#  ['FLL', 'YHM'],
#  ['FLL', 'BEL'],
#  ['FLL', 'MBJ'],
#  ['FLL', 'LGW'],
#  ['FLL', 'ELH'],
#  ['FLL', 'SNU'],
#  ['FLL', 'UIO'],
#  ['FLL', 'ON1'],
#  ['FLL', 'FDF'],
#  ['FLL', 'GCM'],
#  ['FLL', 'ARN'],
#  ['FLL', 'YEM'],
#  ['FLL', 'MGA'],
#  ['FLL', 'BCN'],
#  ['FLL', 'TCB'],
#  ['FLL', 'YKF'],
#  ['FLL', 'KIN'],
#  ['FLL', 'PAP'],
#  ['GVA', 'IAD'],
#  ['GVA', 'SCF'],
#  ['GVA', 'SAV'],
#  ['GVA', 'EWR'],
#  ['GVA', 'PSP'],
#  ['GVA', 'HOU'],
#  ['GVA', 'TEB'],
#  ['GVA', 'HPN'],
#  ['GVA', 'JFK'],
#  ['GVA', 'SFO'],
#  ['KEH', 'ZNA'],
#  ['KEH', 'YHH'],
#  ['KEH', 'YWH'],
#  ['KEH', 'CXH'],
#  ['KEH', 'YYJ'],
#  ['CRP', 'MEX'],
#  ['CRP', 'QRO'],
#  ['CRP', 'SLP'],
#  ['DLC', 'GUM'],
#  ['LAD', 'IAH'],
#  ['AGU', 'AUS'],
#  ['AGU', 'LAX'],
#  ['AGU', 'DFW'],
#  ['AGU', 'IAH'],
#  ['AGU', 'SAT'],
#  ['CLM', 'YYJ'],
#  ['BQN', 'SLU'],
#  ['BQN', 'CUR'],
#  ['BQN', 'BGI'],
#  ['BQN', 'SDQ'],
#  ['BQN', 'POS'],
#  ['BQN', 'AUA'],
#  ['BQN', 'STI'],
#  ['BQN', 'PUJ'],
#  ['SCF', 'YXX'],
#  ['SCF', 'YVR'],
#  ['SCF', 'NTR'],
#  ['SCF', 'YYZ'],
#  ['SCF', 'YUL'],
#  ['GUM', 'PNI'],
#  ['GUM', 'PUS'],
#  ['GUM', 'KIJ'],
#  ['GUM', 'DEL'],
#  ['GUM', 'MNL'],
#  ['GUM', 'KIX'],
#  ['GUM', 'NRT'],
#  ['GUM', 'FUK'],
#  ['GUM', 'TPE'],
#  ['GUM', 'DAC'],
#  ['GUM', 'PVG'],
#  ['GUM', 'CTS'],
#  ['GUM', 'MAJ'],
#  ['GUM', 'YAP'],
#  ['GUM', 'TKK'],
#  ['GUM', 'NGO'],
#  ['GUM', 'ICN'],
#  ['AVP', 'YYZ'],
#  ['YPR', 'KTN'],
#  ['YPR', 'KLW'],
#  ['DSS', 'JFK'],
#  ['DSS', 'IAD'],
#  ['YYR', 'CWA'],
#  ['YYR', 'UXP'],
#  ['YYR', 'BOS'],
#  ['YYR', 'SWF'],
#  ['YYR', 'PHL'],
#  ['MDT', 'YYZ'],
#  ['MTO', 'GDL'],
#  ['PAE', 'PIK'],
#  ['PAE', 'ZRH'],
#  ['PAE', 'TLV'],
#  ['PAE', 'KEF'],
#  ['PAE', 'NGO'],
#  ['JZT', 'QRO'],
#  ['OAK', 'CUN'],
#  ['OAK', 'PVR'],
#  ['OAK', 'MEX'],
#  ['OAK', 'YVR'],
#  ['OAK', 'LGW'],
#  ['OAK', 'KIX'],
#  ['OAK', 'MLM'],
#  ['OAK', 'NRT'],
#  ['OAK', 'GDL'],
#  ['OAK', 'FRA'],
#  ['OAK', 'ARN'],
#  ['OAK', 'PVG'],
#  ['OAK', 'BCN'],
#  ['OAK', 'YYZ'],
#  ['OAK', 'YUL'],
#  ['OAK', 'SJD'],
#  ['OAK', 'FCO'],
#  ['FPR', 'TCB'],
#  ['TCM', 'LIR'],
#  ['MCI', 'CUN'],
#  ['MCI', 'SLW'],
#  ['MCI', 'YYZ'],
#  ['MCI', 'PUJ'],
#  ['MCI', 'YLW'],
#  ['BRO', 'GUA'],
#  ['BRO', 'TRC'],
#  ['BRO', 'GDL'],
#  ['BRO', 'YHM'],
#  ['BRO', 'SAP'],
#  ['BRO', 'TLC'],
#  ['RDU', 'CUN'],
#  ['RDU', 'CDG'],
#  ['RDU', 'LIR'],
#  ['RDU', 'YOW'],
#  ['RDU', 'LHR'],
#  ['RDU', 'YYC'],
#  ['RDU', 'YYZ'],
#  ['RDU', 'YUL'],
#  ['CGO', 'ANC'],
#  ['CGO', 'ORD'],
#  ['OAI', 'PDX'],
#  ['KWI', 'LAX'],
#  ['KWI', 'JFK'],
#  ['LCK', 'CMB'],
#  ['LCK', 'CDG'],
#  ['LCK', 'AMS'],
#  ['LCK', 'OST'],
#  ['LCK', 'LUX'],
#  ['LCK', 'EMA'],
#  ['LCK', 'QRO'],
#  ['LCK', 'SGN'],
#  ['LAR', 'YYZ'],
#  ['KOJ', 'ANC'],
#  ['ADS', 'ANU'],
#  ['STR', 'COS'],
#  ['STR', 'GSP'],
#  ['STR', 'TEB'],
#  ['STR', 'PTK'],
#  ['STR', 'LAS'],
#  ['STR', 'RSW'],
#  ['BWI', 'NAS'],
#  ['BWI', 'MBJ'],
#  ['BWI', 'CUN'],
#  ['BWI', 'MXP'],
#  ['BWI', 'SJO'],
#  ['BWI', 'LIR'],
#  ['BWI', 'BDA'],
#  ['BWI', 'LHR'],
#  ['BWI', 'PTP'],
#  ['BWI', 'AUA'],
#  ['BWI', 'YYZ'],
#  ['BWI', 'PUJ'],
#  ['BWI', 'KEF'],
#  ['BWI', 'FPO'],
#  ['MFE', 'MTY'],
#  ['MFE', 'SAP'],
#  ['MFE', 'MEX'],
#  ['MFE', 'YQG'],
#  ['YLW', 'PHX'],
#  ['YLW', 'LAX'],
#  ['YLW', 'CPR'],
#  ['YLW', 'MWH'],
#  ['YLW', 'GEG'],
#  ['YLW', 'GCC'],
#  ['YLW', 'JAC'],
#  ['KOA', 'NRT'],
#  ['KOA', 'HND'],
#  ['KOA', 'YVR'],
#  ['AZA', 'GUA'],
#  ['AZA', 'MEX'],
#  ['AZA', 'SAL'],
#  ['AZA', 'YEG'],
#  ['AZA', 'YYC'],
#  ['AZA', 'SAP'],
#  ['AZA', 'KEF'],
#  ['ABI', 'MTY'],
#  ['ABI', 'QRO'],
#  ['ABI', 'YYC'],
#  ['BDL', 'CUN'],
#  ['BDL', 'ANU'],
#  ['BDL', 'SXM'],
#  ['BDL', 'YYZ'],
#  ['BDL', 'YUL'],
#  ['BDL', 'KEF'],
#  ['BDL', 'DUB'],
#  ['YQG', 'HSV'],
#  ['YQG', 'LRD'],
#  ['YQG', 'PBI'],
#  ['YQG', 'MEM'],
#  ['YQG', 'GSP'],
#  ['YQG', 'TOL'],
#  ['YQG', 'DTW'],
#  ['YQG', 'MQY'],
#  ['YQG', 'YIP'],
#  ['YQG', 'ELP'],
#  ['RUH', 'JFK'],
#  ['RUH', 'IAD'],
#  ['FWA', 'QRO'],
#  ['FWA', 'TLC'],
#  ['MEC', 'MCO'],
#  ['SFO', 'SYD'],
#  ['SFO', 'PVR'],
#  ['SFO', 'DEL'],
#  ['SFO', 'CDG'],
#  ['SFO', 'NRT'],
#  ['SFO', 'LHR'],
#  ['SFO', 'SAL'],
#  ['SFO', 'IST'],
#  ['SFO', 'PVG'],
#  ['SFO', 'WUH'],
#  ['SFO', 'DXB'],
#  ['SFO', 'ICN'],
#  ['SFO', 'MEX'],
#  ['SFO', 'CUN'],
#  ['SFO', 'PTY'],
#  ['SFO', 'MNL'],
#  ['SFO', 'AMS'],
#  ['SFO', 'ZRH'],
#  ['SFO', 'FRA'],
#  ['SFO', 'YYC'],
#  ['SFO', 'CPH'],
#  ['SFO', 'AKL'],
#  ['SFO', 'YYZ'],
#  ['SFO', 'RTM'],
#  ['SFO', 'YUL'],
#  ['SFO', 'SJD'],
#  ['SFO', 'DUB'],
#  ['SFO', 'CAN'],
#  ['SFO', 'KIX'],
#  ['SFO', 'NAN'],
#  ['SFO', 'GDL'],
#  ['SFO', 'CSL'],
#  ['SFO', 'YYJ'],
#  ['SFO', 'TAO'],
#  ['SFO', 'KEF'],
#  ['SFO', 'HUX'],
#  ['SFO', 'YVR'],
#  ['SFO', 'YWG'],
#  ['SFO', 'TPE'],
#  ['SFO', 'TLV'],
#  ['SFO', 'SIN'],
#  ['SFO', 'HND'],
#  ['SFO', 'MUC'],
#  ['STL', 'HUX'],
#  ['STL', 'MBJ'],
#  ['STL', 'PVR'],
#  ['STL', 'CUN'],
#  ['STL', 'YWG'],
#  ['STL', 'ANU'],
#  ['STL', 'YOW'],
#  ['STL', 'YYZ'],
#  ['STL', 'YKF'],
#  ['STL', 'YUL'],
#  ['STL', 'PUJ'],
#  ['RFD', 'MBJ'],
#  ['RFD', 'CUN'],
#  ['RFD', 'PUJ'],
#  ['ICN', 'IAD'],
#  ['ICN', 'MEM'],
#  ['ICN', 'ORD'],
#  ['ICN', 'LAX'],
#  ['ICN', 'ANC'],
#  ['ICN', 'CVG'],
#  ['ICN', 'DFW'],
#  ['ICN', 'DTW'],
#  ['ICN', 'MSP'],
#  ['ICN', 'SPN'],
#  ['ICN', 'JFK'],
#  ['ICN', 'LAS'],
#  ['ICN', 'HNL'],
#  ['MTJ', 'NAS'],
#  ['ACT', 'REC'],
#  ['YYB', 'PBI'],
#  ['YCD', 'BFI'],
#  ['YCD', 'PSP'],
#  ['ANC', 'NRT'],
#  ['ANC', 'PVG'],
#  ['ANC', 'YHZ'],
#  ['ANC', 'WUH'],
#  ['ANC', 'NGO'],
#  ['ANC', 'MEX'],
#  ['ANC', 'MNL'],
#  ['ANC', 'YYC'],
#  ['ANC', 'YYZ'],
#  ['ANC', 'MFM'],
#  ['ANC', 'KHH'],
#  ['ANC', 'CAN'],
#  ['ANC', 'KIX'],
#  ['ANC', 'GDL'],
#  ['ANC', 'HGH'],
#  ['ANC', 'YNY'],
#  ['ANC', 'YWG'],
#  ['ANC', 'TPE'],
#  ['ANC', 'SZX'],
#  ['PDX', 'MEX'],
#  ['PDX', 'PVR'],
#  ['PDX', 'YVR'],
#  ['PDX', 'AMS'],
#  ['PDX', 'NRT'],
#  ['PDX', 'GDL'],
#  ['PDX', 'YYC'],
#  ['PDX', 'YYZ'],
#  ['PDX', 'SJD'],
#  ['PDX', 'KEF'],
#  ['YMX', 'FXE'],
#  ['YMX', 'DSM'],
#  ['YMX', 'MEM'],
#  ['YMX', 'ROC'],
#  ['YMX', 'EWR'],
#  ['YMX', 'MYR'],
#  ['YMX', 'CVG'],
#  ['YMX', 'BOS'],
#  ['YMX', 'SDF'],
#  ['YMX', 'YIP'],
#  ['YMX', 'IND'],
#  ['SVG', 'SWF'],
#  ['SVG', 'IAH'],
#  ['YNY', 'JFK'],
#  ['YNY', 'MSP'],
#  ['SYR', 'YYZ'],
#  ['SYR', 'YUL'],
#  ['SYR', 'YOW'],
#  ['PSA', 'OPF'],
#  ['BTR', 'NAS'],
#  ['TAB', 'JFK'],
#  ['TAB', 'LGA'],
#  ['TAB', 'OPF'],
#  ['RIC', 'YYZ'],
#  ['RIC', 'LIR'],
#  ['SHV', 'MTY'],
#  ['SHV', 'SLP'],
#  ['SHV', 'SLW'],
#  ['SHV', 'QRO'],
#  ['SHV', 'YUL'],
#  ['SHV', 'TLC'],
#  ['LEX', 'YYZ'],
#  ['LEX', 'ARN'],
#  ['LEX', 'NAS'],
#  ['NTR', 'TEB'],
#  ['NTR', 'SAT'],
#  ['CXH', 'LKE'],
#  ['TAM', 'LRD'],
#  ['TAM', 'IAH'],
#  ['N2C', 'BIM'],
#  ['ORL', 'YYZ'],
#  ['ORL', 'PLS'],
#  ['LKE', 'YWH'],
#  ['LKE', 'YYJ'],
#  ['LKE', 'YIG'],
#  ['SPI', 'CUN'],
#  ['AMD', 'EWR'],
#  ['BRI', 'CHS'],
#  ['FTW', 'SAL'],
#  ['FTW', 'SAP'],
#  ['ACC', 'JFK'],
#  ['ACC', 'IAD'],
#  ['STT', 'NEV'],
#  ['STT', 'SKB'],
#  ['STT', 'AXA'],
#  ['STT', 'SBH'],
#  ['ALB', 'YYZ'],
#  ['ALB', 'LGW'],
#  ['APW', 'HNL'],
#  ['PIK', 'LAX'],
#  ['PIK', 'DFW'],
#  ['PIK', 'ORD'],
#  ['HOU', 'MBJ'],
#  ['HOU', 'CUN'],
#  ['HOU', 'PVR'],
#  ['HOU', 'MEX'],
#  ['HOU', 'SJO'],
#  ['HOU', 'LIR'],
#  ['HOU', 'BZE'],
#  ['HOU', 'YXU'],
#  ['HOU', 'AUA'],
#  ['HOU', 'YYZ'],
#  ['HOU', 'SJD'],
#  ['SDF', 'MTY'],
#  ['SDF', 'CGN'],
#  ['SDF', 'MEX'],
#  ['SDF', 'YVR'],
#  ['SDF', 'YWG'],
#  ['SDF', 'CDG'],
#  ['SDF', 'GDL'],
#  ['SDF', 'YXU'],
#  ['SDF', 'YYC'],
#  ['SDF', 'STN'],
#  ['SDF', 'YYZ'],
#  ['SDF', 'YHM'],
#  ['SDF', 'PUJ'],
#  ['SDF', 'EMA'],
#  ['SDF', 'DXB'],
#  ['SDF', 'LGG'],
#  ['YTZ', 'IAD'],
#  ['YTZ', 'EWR'],
#  ['YTZ', 'MDW'],
#  ['YTZ', 'MYR'],
#  ['YTZ', 'BOS'],
#  ['YTZ', 'TEB'],
#  ['YTZ', 'MLB'],
#  ['YTZ', 'HPN'],
#  ['YTZ', 'BTV'],
#  ['BLM', 'YYZ'],
#  ['ZCL', 'LAX'],
#  ['ZCL', 'MDW'],
#  ['ZCL', 'SJC'],
#  ['ZCL', 'DFW'],
#  ['LEJ', 'LAX'],
#  ['LEJ', 'CVG'],
#  ['LEJ', 'ORD'],
#  ['SMF', 'HUX'],
#  ['SMF', 'MEX'],
#  ['SMF', 'PVR'],
#  ['SMF', 'YVR'],
#  ['SMF', 'SJO'],
#  ['SMF', 'GCM'],
#  ['SMF', 'GDL'],
#  ['SMF', 'YYC'],
#  ['SMF', 'SJD'],
#  ['LTO', 'LAX'],
#  ['ROC', 'YYZ'],
#  ['ROC', 'YUL'],
#  ['ROC', 'YOW'],
#  ['BFI', 'GND'],
#  ['BFI', 'YVR'],
#  ['BFI', 'BHX'],
#  ['BFI', 'OSL'],
#  ['BFI', 'HND'],
#  ['BFI', 'YYC'],
#  ['BFI', 'YYZ'],
#  ['BFI', 'YYJ'],
#  ['BFI', 'KEF'],
#  ['CVG', 'CDG'],
#  ['CVG', 'NRT'],
#  ['CVG', 'YHZ'],
#  ['CVG', 'NGO'],
#  ['CVG', 'MEX'],
#  ['CVG', 'CUN'],
#  ['CVG', 'SJO'],
#  ['CVG', 'AMS'],
#  ['CVG', 'FRA'],
#  ['CVG', 'ZRH'],
#  ['CVG', 'YYC'],
#  ['CVG', 'YYZ'],
#  ['CVG', 'YHM'],
#  ['CVG', 'YUL'],
#  ['CVG', 'EMA'],
#  ['CVG', 'PUJ'],
#  ['CVG', 'SHJ'],
#  ['CVG', 'GDL'],
#  ['CVG', 'BAH'],
#  ['CVG', 'QRO'],
#  ['CVG', 'NAS'],
#  ['CVG', 'YWG'],
#  ['CVG', 'BRU'],
#  ['CVG', 'YEG'],
#  ['TPE', 'ORD'],
#  ['TPE', 'LAX'],
#  ['TPE', 'IAH'],
#  ['TPE', 'ONT'],
#  ['TPE', 'JFK'],
#  ['TPE', 'HNL'],
#  ['DCA', 'YYZ'],
#  ['DCA', 'YUL'],
#  ['DCA', 'NAS'],
#  ['DCA', 'YOW'],
#  ['BOS', 'BOG'],
#  ['BOS', 'PVR'],
#  ['BOS', 'MAD'],
#  ['BOS', 'DEL'],
#  ['BOS', 'PAP'],
#  ['BOS', 'CDG'],
#  ['BOS', 'NRT'],
#  ['BOS', 'YOW'],
#  ['BOS', 'LHR'],
#  ['BOS', 'IST'],
#  ['BOS', 'YQB'],
#  ['BOS', 'PVG'],
#  ['BOS', 'AUA'],
#  ['BOS', 'STI'],
#  ['BOS', 'YHZ'],
#  ['BOS', 'DXB'],
#  ['BOS', 'MEX'],
#  ['BOS', 'CUN'],
#  ['BOS', 'PTY'],
#  ['BOS', 'SNN'],
#  ['BOS', 'AMS'],
#  ['BOS', 'ANU'],
#  ['BOS', 'LIR'],
#  ['BOS', 'ZRH'],
#  ['BOS', 'FRA'],
#  ['BOS', 'VKO'],
#  ['BOS', 'CPH'],
#  ['BOS', 'YYZ'],
#  ['BOS', 'TER'],
#  ['BOS', 'YUL'],
#  ['BOS', 'PUJ'],
#  ['BOS', 'DUB'],
#  ['BOS', 'SVO'],
#  ['BOS', 'RAI'],
#  ['BOS', 'MBJ'],
#  ['BOS', 'MXP'],
#  ['BOS', 'LGW'],
#  ['BOS', 'SDQ'],
#  ['BOS', 'DOH'],
#  ['BOS', 'PDL'],
#  ['BOS', 'BDA'],
#  ['BOS', 'POP'],
#  ['BOS', 'UVF'],
#  ['BOS', 'FCO'],
#  ['BOS', 'KEF'],
#  ['BOS', 'NAS'],
#  ['BOS', 'BGI'],
#  ['BOS', 'LIS'],
#  ['BOS', 'GCM'],
#  ['BOS', 'TLV'],
#  ['BOS', 'PLS'],
#  ['BOS', 'MUC'],
#  ['DHN', 'KEF'],
#  ['ZLO', 'LAX'],
#  ['ZLO', 'MSP'],
#  ['ZLO', 'IAH'],
#  ['ZLO', 'PHX'],
#  ['TBU', 'PPG'],
#  ['SUS', 'YXU'],
#  ['SUS', 'PLS'],
#  ['EVV', 'AUA'],
#  ['EVV', 'SLW'],
#  ['EVV', 'SLP'],
#  ['BEG', 'JFK'],
#  ['YQM', 'MCO'],
#  ['HKD', 'HNL'],
#  ['CHS', 'TAR'],
#  ['CHS', 'CUN'],
#  ['CHS', 'YHZ'],
#  ['CHS', 'PUJ'],
#  ['MLB', 'BIM'],
#  ['MLB', 'YUL'],
#  ['MLB', 'MHH'],
#  ['MAJ', 'HNL'],
#  ['PUS', 'SPN'],
#  ['SBA', 'YVR'],
#  ['YQX', 'PHL'],
#  ['YQX', 'DTW'],
#  ['YQX', 'ORD'],
#  ['KTN', 'YXS'],
#  ['KTN', 'YVR'],
#  ['JED', 'JFK'],
#  ['JED', 'IAD'],
#  ['JED', 'LAX'],
#  ['LEB', 'YYZ'],
#  ['ORY', 'EWR'],
#  ['ORY', 'JFK'],
#  ['SWF', 'BGO'],
#  ['SWF', 'SNN'],
#  ['SWF', 'BFS'],
#  ['SWF', 'FDF'],
#  ['SWF', 'LGW'],
#  ['SWF', 'OSL'],
#  ['SWF', 'BOD'],
#  ['SWF', 'ARN'],
#  ['SWF', 'PTP'],
#  ['SWF', 'CPH'],
#  ['SWF', 'KEF'],
#  ['SWF', 'DUB'],
#  ['YLS', 'JAX'],
#  ['YLS', 'SUA'],
#  ['FXE', 'NAS'],
#  ['FXE', 'YYZ'],
#  ['FXE', 'DUB'],
#  ['FXE', 'YOW'],
#  ['SZG', 'OPF'],
#  ['JAX', 'SXM'],
#  ['JAX', 'YYZ'],
#  ['JAX', 'MHH'],
#  ['JAX', 'TCB'],
#  ['JAX', 'BIM'],
#  ['LYS', 'ISO'],
#  ['XMN', 'LAX'],
#  ['LBG', 'BGR'],
#  ['LBG', 'EWR'],
#  ['LBG', 'LAX'],
#  ['LBG', 'TEB'],
#  ['LBG', 'JFK'],
#  ['LBG', 'PHL'],
#  ['CSL', 'BUR'],
#  ['BBU', 'IAD'],
#  ['ERI', 'YYZ'],
#  ['FAB', 'OPF'],
#  ['FAB', 'SAV'],
#  ['FAB', 'LAX'],
#  ['FAB', 'TEB'],
#  ['FAB', 'IND'],
#  ['TN8', 'GGT'],
#  ['JFK', 'MTY'],
#  ['JFK', 'BOG'],
#  ['JFK', 'DEL'],
#  ...]

# %%
dulles_ego = nx.ego_graph(mG, 'IAD')

# %%
pos = nx.spring_layout(dulles_ego)

# %%
nx.draw(dulles_ego)

# %%
dulles_df = pd.DataFrame.from_dict(dict(dulles_ego.nodes.data()), orient='index')
dulles_df.head()
# Out:
#           long        lat  degree  in degree  out degree  closeness  \
# ACC  -0.166786   5.605190       8   0.006745    0.006745   0.267422
# ADD  38.799301   8.977890      12   0.010118    0.010118   0.280204
# AMS   4.763890  52.308601     221   0.200675    0.172007   0.339060
# AUA -70.015198  12.501400     144   0.123103    0.119730   0.317778
# AUH  54.651100  24.433001      31   0.025295    0.026981   0.293108
#
#      betweenness
# ACC     0.000020
# ADD     0.000108
# AMS     0.009455
# AUA     0.004975
# AUH     0.000276

# %%
from osgeo import ogr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-38-52abdaacf855> in <module>()
# ----> 1 from osgeo import ogr
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\osgeo\__init__.py in <module>()
#      19                 fp.close()
#      20             return _mod
# ---> 21     _gdal = swig_import_helper()
#      22     del swig_import_helper
#      23 else:
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\osgeo\__init__.py in swig_import_helper()
#      15         if fp is not None:
#      16             try:
# ---> 17                 _mod = imp.load_module('_gdal', fp, pathname, description)
#      18             finally:
#      19                 fp.close()
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\imp.py in load_module(name, file, filename, details)
#     241                 return load_dynamic(name, filename, opened_file)
#     242         else:
# --> 243             return load_dynamic(name, filename, file)
#     244     elif type_ == PKG_DIRECTORY:
#     245         return load_package(name, filename)
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\imp.py in load_dynamic(name, path, file)
#     341         spec = importlib.machinery.ModuleSpec(
#     342             name=name, loader=loader, origin=path)
# --> 343         return _load(spec)
#     344
#     345 else:
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
nx.readwrite.nx_shp.write_shp(mG, '/Shapefiles')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\networkx\readwrite\nx_shp.py in write_shp(G, outdir)
#     217     try:
# --> 218         from osgeo import ogr
#     219     except ImportError:
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\osgeo\__init__.py in <module>()
#      20             return _mod
# ---> 21     _gdal = swig_import_helper()
#      22     del swig_import_helper
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\osgeo\__init__.py in swig_import_helper()
#      16             try:
# ---> 17                 _mod = imp.load_module('_gdal', fp, pathname, description)
#      18             finally:
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\imp.py in load_module(name, file, filename, details)
#     242         else:
# --> 243             return load_dynamic(name, filename, file)
#     244     elif type_ == PKG_DIRECTORY:
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\imp.py in load_dynamic(name, path, file)
#     342             name=name, loader=loader, origin=path)
# --> 343         return _load(spec)
#     344
#
# ImportError: DLL load failed: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-7177f4d73097> in <module>()
# ----> 1 nx.readwrite.nx_shp.write_shp(mG, '/Shapefiles')
#
# c:\users\jame9353\appdata\local\esri\conda\envs\networkanalysis\lib\site-packages\networkx\readwrite\nx_shp.py in write_shp(G, outdir)
#     218         from osgeo import ogr
#     219     except ImportError:
# --> 220         raise ImportError("write_shp requires OGR: http://www.gdal.org/")
#     221     # easier to debug in python if ogr throws exceptions
#     222     ogr.UseExceptions()
#
# ImportError: write_shp requires OGR: http://www.gdal.org/

# %%
import json
from networkx.readwrite import json_graph
out_json = json_graph.node_link_data(mG, attrs={'link': 'edges', 'source': 'from', 'target': 'to'})
s2 = json.dumps(out_json, default={'link': 'edges', 'source': 'from', 'target': 'to'})

with open('networkx_d3.json', 'w') as json_file:
                        json.dump(s2, json_file)
